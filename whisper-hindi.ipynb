# %%
# !pip install openai-whisper
import whisper

# Load Whisper model

model = whisper.load_model("small") # can be "base", "small", "medium", "large"

# Translate English audio to Hindi text

result = model.transcribe("/content/1.mp3", task="translate", language="hi")

print("Translated to Hindi:", result["text"])
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 31.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=4690485692df65897e6538aad57f8c305cf8d37978e7806a3b2e60bb89dcffe6
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...
# 100%|███████████████████████████████████████| 461M/461M [00:05<00:00, 90.4MiB/s]
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Translated to Hindi:  I am fighting with the boss. I am talking about this incident.
